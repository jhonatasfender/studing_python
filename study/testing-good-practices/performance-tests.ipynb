# %%
import random

random.seed(1000)

long_list = [random.randint(0,50) for i in range(100000)]
long_list
# Out:
# [49,
#  27,
#  42,
#  48,
#  6,
#  25,
#  22,
#  4,
#  29,
#  10,
#  34,
#  27,
#  8,
#  14,
#  42,
#  15,
#  23,
#  43,
#  31,
#  12,
#  43,
#  42,
#  23,
#  14,
#  29,
#  11,
#  2,
#  43,
#  47,
#  31,
#  9,
#  29,
#  45,
#  45,
#  26,
#  44,
#  12,
#  1,
#  48,
#  34,
#  29,
#  45,
#  49,
#  13,
#  34,
#  11,
#  44,
#  45,
#  6,
#  16,
#  10,
#  18,
#  5,
#  0,
#  20,
#  1,
#  40,
#  16,
#  18,
#  33,
#  49,
#  49,
#  35,
#  7,
#  12,
#  18,
#  24,
#  20,
#  42,
#  14,
#  14,
#  22,
#  39,
#  31,
#  7,
#  18,
#  24,
#  29,
#  23,
#  31,
#  38,
#  17,
#  30,
#  21,
#  0,
#  3,
#  9,
#  28,
#  41,
#  45,
#  4,
#  14,
#  18,
#  50,
#  1,
#  23,
#  8,
#  13,
#  8,
#  40,
#  47,
#  32,
#  21,
#  22,
#  21,
#  18,
#  48,
#  48,
#  44,
#  30,
#  43,
#  12,
#  25,
#  48,
#  4,
#  14,
#  15,
#  19,
#  19,
#  49,
#  26,
#  20,
#  0,
#  35,
#  37,
#  45,
#  10,
#  6,
#  31,
#  26,
#  39,
#  29,
#  24,
#  25,
#  33,
#  1,
#  19,
#  3,
#  2,
#  12,
#  12,
#  6,
#  21,
#  12,
#  9,
#  6,
#  4,
# ...
